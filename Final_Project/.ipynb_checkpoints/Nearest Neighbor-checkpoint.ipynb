# %% [markdown]
# # Pretrained VGGNet

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm

vgg_dir = 'tensorflow_vgg/'
# Make sure vgg exists
if not isdir(vgg_dir):
    raise Exception("VGG directory doesn't exist!")

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(vgg_dir + "vgg16.npy"):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='VGG16 Parameters') as pbar:
        urlretrieve(
            'https://s3.amazonaws.com/content.udacity-data.com/nd101/vgg16.npy',
            vgg_dir + 'vgg16.npy',
            pbar.hook)
else:
    print("Parameter file already exists!")
# Out:
# Parameter file already exists!

# %%
import os

import numpy as np
import tensorflow as tf

from tensorflow_vgg import vgg16
from tensorflow_vgg import utils

# %%
data_dir = 'train/'
contents = os.listdir(data_dir)
classes = [each for each in contents if os.path.isdir(data_dir + each)]

# %%
print(classes)
# Out:
# ['real', 'fake']

# %%
# Set the batch size higher if you can fit in in your GPU memory
batch_size = 10
codes_list = []
labels = []
batch = []

codes = None

with tf.Session() as sess:
    vgg = vgg16.Vgg16()
    input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
    with tf.name_scope("content_vgg"):
        vgg.build(input_)

    for each in classes:
        print("Starting {} images".format(each))
        class_path = data_dir + each
        files = os.listdir(class_path)
        for ii, file in enumerate(files, 1):
            # Add images to the current batch
            # utils.load_image crops the input images for us, from the center
            img = utils.load_image(os.path.join(class_path, file))
            batch.append(img.reshape((1, 224, 224, 3)))
            labels.append(each)
            
            # Running the batch through the network to get the codes
            if ii % batch_size == 0 or ii == len(files):
                images = np.concatenate(batch)

                feed_dict = {input_: images}
                codes_batch = sess.run(vgg.relu6, feed_dict=feed_dict)
                
                # Here I'm building an array of the codes
                if codes is None:
                    codes = codes_batch
                else:
                    codes = np.concatenate((codes, codes_batch))
                
                # Reset to start building the next batch
                batch = []
                print('{} images processed'.format(ii))
# Out:
# /Users/cathylin/Desktop/EECS 349/Final_Project/tensorflow_vgg/vgg16.npy
# npy file loaded
# build model started
# build model finished: 4s
# Starting real images
# /anaconda3/envs/dlnd/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# 380 images processed
# 390 images processed
# 400 images processed
# 410 images processed
# 420 images processed
# 430 images processed
# 440 images processed
# 450 images processed
# 460 images processed
# 470 images processed
# 480 images processed
# 490 images processed
# 500 images processed
# 510 images processed
# 512 images processed
# Starting fake images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 260 images processed
# 270 images processed
# 280 images processed
# 290 images processed
# 300 images processed
# 310 images processed
# 320 images processed
# 330 images processed
# 340 images processed
# 350 images processed
# 360 images processed
# 370 images processed
# 380 images processed
# 390 images processed
# 400 images processed
# 410 images processed
# 420 images processed
# 430 images processed
# 440 images processed
# 450 images processed
# 460 images processed
# 470 images processed
# 480 images processed
# 490 images processed
# 500 images processed
# 510 images processed
# 512 images processed

# %%
# write codes to file
with open('codes', 'w') as f:
    codes.tofile(f)
    
# write labels to file
import csv
with open('labels', 'w') as f:
    writer = csv.writer(f, delimiter='\n')
    writer.writerow(labels)

# %% [markdown]
# ## Building the Classifier

# %%
print(labels)
# Out:
# ['real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', ...

# %%
# read codes and labels from file
import csv

with open('labels') as f:
    reader = csv.reader(f, delimiter='\n')
    labels = np.array([each for each in reader if len(each) > 0]).squeeze()
with open('codes') as f:
    codes = np.fromfile(f, dtype=np.float32)
    codes = codes.reshape((len(labels), -1))

# %%
print(codes.shape)
# Out:
# (1024, 4096)

# %%
print(codes[0])
# Out:
# [0.        0.        1.5262582 ... 2.821091  0.        2.3106177]

# %%
print(codes[0].shape)
# Out:
# (4096,)

# %%
print(labels[0])
# Out:
# real

# %%
print(sum(abs(codes[0]-codes[1])))
# Out:
# 6011.737014427781

# %%
print(sum(abs(codes[0]-codes[0])))
# Out:
# 0.0

# %%
print(sum(abs(codes[0]-codes[150])))
# Out:
# 6886.401059038937

# %%
from numpy.linalg import norm

# %%
print(norm(codes[0]-codes[1]))
# Out:
# 161.04782

# %%
print(norm(codes[0]-codes[150]))
# Out:
# 181.32484

# %% [markdown]
# ### First, convert all the images in the test dataset to vectors.

# %%
data_dir = 'test/'
contents = os.listdir(data_dir)
classes2 = [each for each in contents if os.path.isdir(data_dir + each)]

# %%
print(classes2)
# Out:
# ['real', 'fake']

# %%
# Set the batch size higher if you can fit in in your GPU memory
batch_size = 10
codes_list = []
labels = []
batch = []

codes = None

with tf.Session() as sess:
    vgg = vgg16.Vgg16()
    input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
    with tf.name_scope("content_vgg"):
        vgg.build(input_)

    for each in classes:
        print("Starting {} images".format(each))
        class_path = data_dir + each
        files = os.listdir(class_path)
        for ii, file in enumerate(files, 1):
            # Add images to the current batch
            # utils.load_image crops the input images for us, from the center
            img = utils.load_image(os.path.join(class_path, file))
            batch.append(img.reshape((1, 224, 224, 3)))
            labels.append(each)
            
            # Running the batch through the network to get the codes
            if ii % batch_size == 0 or ii == len(files):
                images = np.concatenate(batch)

                feed_dict = {input_: images}
                codes_batch = sess.run(vgg.relu6, feed_dict=feed_dict)
                
                # Here I'm building an array of the codes
                if codes is None:
                    codes = codes_batch
                else:
                    codes = np.concatenate((codes, codes_batch))
                
                # Reset to start building the next batch
                batch = []
                print('{} images processed'.format(ii))
# Out:
# /Users/cathylin/Desktop/EECS 349/Final_Project/tensorflow_vgg/vgg16.npy
# npy file loaded
# build model started
# build model finished: 3s
# Starting real images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 256 images processed
# Starting fake images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 100 images processed
# 110 images processed
# 120 images processed
# 130 images processed
# 140 images processed
# 150 images processed
# 160 images processed
# 170 images processed
# 180 images processed
# 190 images processed
# 200 images processed
# 210 images processed
# 220 images processed
# 230 images processed
# 240 images processed
# 250 images processed
# 256 images processed

# %%
# write codes to file
with open('codes2', 'w') as f:
    codes.tofile(f)
    
# write labels to file
import csv
with open('labels2', 'w') as f:
    writer = csv.writer(f, delimiter='\n')
    writer.writerow(labels)

# %%
print(codes.shape)
# Out:
# (512, 4096)

# %% [markdown]
# ## Try 1-Nearest Neighbor

# %%
# read codes and labels from file
import csv

with open('labels') as f:
    reader = csv.reader(f, delimiter='\n')
    labels = np.array([each for each in reader if len(each) > 0]).squeeze()
with open('codes') as f:
    codes = np.fromfile(f, dtype=np.float32)
    codes = codes.reshape((len(labels), -1))

# %%
# read codes and labels from file
import csv

with open('labels2') as f:
    reader = csv.reader(f, delimiter='\n')
    labels2 = np.array([each for each in reader if len(each) > 0]).squeeze()
with open('codes2') as f:
    codes2 = np.fromfile(f, dtype=np.float32)
    codes2 = codes2.reshape((len(labels2), -1))

# %%
print(codes.shape)
# Out:
# (1024, 4096)

# %%
print(codes2.shape)
# Out:
# (512, 4096)

# %%
print(labels2.shape)
# Out:
# (512,)

# %%
print(len(codes))
# Out:
# 1024

# %%
print(len(codes2))
# Out:
# 512

# %% [markdown]
# ### Using Manhattan distances (L1 distances)
# ### Euclidean distances (L2 distances)

# %%
#重置图（这个是为了用于多次运行）
tf.reset_default_graph()

#使用训练集数目为160条
#使用验证集（测试集）数目为80

xtr = tf.placeholder('float', [None, 4096])
xte = tf.placeholder('float', [4096])

#计算各个对应位置的距离（减法使用广播形式）
#底下俩作用相同
distance = tf.reduce_sum(tf.abs(tf.subtract(xtr, xte)), reduction_indices=1)

#寻找距离最近（即最相似的行所在位置）
pred = tf.arg_min(distance, 0)

accuracy = 0.

#初始化
init = tf.global_variables_initializer()


with tf.Session() as sess:
    sess.run(init)

    for i in range(len(codes2)):
        #计算最相近的所在行位置
        nn_index = sess.run(pred, feed_dict={xtr:codes, xte: codes2[i, :]})

        #取出测试集上最相近行对应的label与真是label对比
        print('Test', i, 'Prediction: ', labels[nn_index], \
               'True Class: ', labels2[i])
        if labels[nn_index] == labels2[i]:
            accuracy += 1./len(codes2)
    print('Done!')
    print('Accuracy: ', accuracy)
# Out:
# WARNING:tensorflow:From <ipython-input-32-f276d1be3a65>:15: arg_min (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmin` instead
# Test 0 Prediction:  real True Class:  real
# Test 1 Prediction:  real True Class:  real
# Test 2 Prediction:  real True Class:  real
# Test 3 Prediction:  real True Class:  real
# Test 4 Prediction:  fake True Class:  real
# Test 5 Prediction:  real True Class:  real
# Test 6 Prediction:  real True Class:  real
# Test 7 Prediction:  real True Class:  real
# Test 8 Prediction:  real True Class:  real
# Test 9 Prediction:  real True Class:  real
# Test 10 Prediction:  real True Class:  real
# Test 11 Prediction:  fake True Class:  real
# Test 12 Prediction:  real True Class:  real
# Test 13 Prediction:  real True Class:  real
# Test 14 Prediction:  real True Class:  real
# Test 15 Prediction:  real True Class:  real
# Test 16 Prediction:  real True Class:  real
# Test 17 Prediction:  real True Class:  real
# Test 18 Prediction:  fake True Class:  real
# Test 19 Prediction:  real True Class:  real
# Test 20 Prediction:  real True Class:  real
# Test 21 Prediction:  real True Class:  real
# Test 22 Prediction:  real True Class:  real
# Test 23 Prediction:  real True Class:  real
# Test 24 Prediction:  real True Class:  real
# Test 25 Prediction:  real True Class:  real
# Test 26 Prediction:  real True Class:  real
# Test 27 Prediction:  real True Class:  real
# Test 28 Prediction:  real True Class:  real
# Test 29 Prediction:  real True Class:  real
# Test 30 Prediction:  real True Class:  real
# Test 31 Prediction:  real True Class:  real
# Test 32 Prediction:  real True Class:  real
# Test 33 Prediction:  real True Class:  real
# Test 34 Prediction:  real True Class:  real
# Test 35 Prediction:  real True Class:  real
# Test 36 Prediction:  real True Class:  real
# Test 37 Prediction:  real True Class:  real
# Test 38 Prediction:  real True Class:  real
# Test 39 Prediction:  real True Class:  real
# Test 40 Prediction:  real True Class:  real
# Test 41 Prediction:  real True Class:  real
# Test 42 Prediction:  real True Class:  real
# Test 43 Prediction:  real True Class:  real
# Test 44 Prediction:  real True Class:  real
# Test 45 Prediction:  real True Class:  real
# Test 46 Prediction:  real True Class:  real
# Test 47 Prediction:  real True Class:  real
# Test 48 Prediction:  real True Class:  real
# Test 49 Prediction:  real True Class:  real
# Test 50 Prediction:  real True Class:  real
# Test 51 Prediction:  real True Class:  real
# Test 52 Prediction:  real True Class:  real
# Test 53 Prediction:  real True Class:  real
# Test 54 Prediction:  real True Class:  real
# Test 55 Prediction:  real True Class:  real
# Test 56 Prediction:  real True Class:  real
# Test 57 Prediction:  real True Class:  real
# Test 58 Prediction:  real True Class:  real
# Test 59 Prediction:  fake True Class:  real
# Test 60 Prediction:  real True Class:  real
# Test 61 Prediction:  real True Class:  real
# Test 62 Prediction:  real True Class:  real
# Test 63 Prediction:  real True Class:  real
# Test 64 Prediction:  real True Class:  real
# Test 65 Prediction:  real True Class:  real
# Test 66 Prediction:  real True Class:  real
# Test 67 Prediction:  real True Class:  real
# Test 68 Prediction:  real True Class:  real
# Test 69 Prediction:  real True Class:  real
# Test 70 Prediction:  real True Class:  real
# Test 71 Prediction:  real True Class:  real
# Test 72 Prediction:  real True Class:  real
# Test 73 Prediction:  real True Class:  real
# Test 74 Prediction:  real True Class:  real
# Test 75 Prediction:  real True Class:  real
# Test 76 Prediction:  real True Class:  real
# Test 77 Prediction:  real True Class:  real
# Test 78 Prediction:  real True Class:  real
# Test 79 Prediction:  real True Class:  real
# Test 80 Prediction:  real True Class:  real
# Test 81 Prediction:  real True Class:  real
# Test 82 Prediction:  real True Class:  real
# Test 83 Prediction:  real True Class:  real
# Test 84 Prediction:  real True Class:  real
# Test 85 Prediction:  real True Class:  real
# Test 86 Prediction:  real True Class:  real
# Test 87 Prediction:  real True Class:  real
# Test 88 Prediction:  real True Class:  real
# Test 89 Prediction:  real True Class:  real
# Test 90 Prediction:  real True Class:  real
# Test 91 Prediction:  real True Class:  real
# Test 92 Prediction:  real True Class:  real
# Test 93 Prediction:  real True Class:  real
# Test 94 Prediction:  real True Class:  real
# Test 95 Prediction:  real True Class:  real
# Test 96 Prediction:  fake True Class:  real
# Test 97 Prediction:  real True Class:  real
# Test 98 Prediction:  real True Class:  real
# Test 99 Prediction:  real True Class:  real
# Test 100 Prediction:  real True Class:  real
# Test 101 Prediction:  real True Class:  real
# Test 102 Prediction:  real True Class:  real
# Test 103 Prediction:  real True Class:  real
# Test 104 Prediction:  real True Class:  real
# Test 105 Prediction:  real True Class:  real
# Test 106 Prediction:  real True Class:  real
# Test 107 Prediction:  real True Class:  real
# Test 108 Prediction:  real True Class:  real
# Test 109 Prediction:  real True Class:  real
# Test 110 Prediction:  real True Class:  real
# Test 111 Prediction:  real True Class:  real
# Test 112 Prediction:  real True Class:  real
# Test 113 Prediction:  real True Class:  real
# Test 114 Prediction:  real True Class:  real
# Test 115 Prediction:  real True Class:  real
# Test 116 Prediction:  real True Class:  real
# Test 117 Prediction:  real True Class:  real
# Test 118 Prediction:  real True Class:  real
# Test 119 Prediction:  real True Class:  real
# Test 120 Prediction:  real True Class:  real
# Test 121 Prediction:  real True Class:  real
# Test 122 Prediction:  fake True Class:  real
# Test 123 Prediction:  real True Class:  real
# Test 124 Prediction:  real True Class:  real
# Test 125 Prediction:  real True Class:  real
# Test 126 Prediction:  fake True Class:  real
# Test 127 Prediction:  real True Class:  real
# Test 128 Prediction:  fake True Class:  real
# Test 129 Prediction:  real True Class:  real
# Test 130 Prediction:  real True Class:  real
# Test 131 Prediction:  real True Class:  real
# Test 132 Prediction:  real True Class:  real
# Test 133 Prediction:  real True Class:  real
# Test 134 Prediction:  real True Class:  real
# Test 135 Prediction:  real True Class:  real
# Test 136 Prediction:  real True Class:  real
# Test 137 Prediction:  real True Class:  real
# Test 138 Prediction:  real True Class:  real
# Test 139 Prediction:  real True Class:  real
# Test 140 Prediction:  real True Class:  real
# Test 141 Prediction:  real True Class:  real
# Test 142 Prediction:  real True Class:  real
# Test 143 Prediction:  real True Class:  real
# Test 144 Prediction:  real True Class:  real
# Test 145 Prediction:  real True Class:  real
# Test 146 Prediction:  real True Class:  real
# Test 147 Prediction:  real True Class:  real
# Test 148 Prediction:  real True Class:  real
# Test 149 Prediction:  real True Class:  real
# Test 150 Prediction:  real True Class:  real
# Test 151 Prediction:  real True Class:  real
# Test 152 Prediction:  real True Class:  real
# Test 153 Prediction:  real True Class:  real
# Test 154 Prediction:  real True Class:  real
# Test 155 Prediction:  fake True Class:  real
# Test 156 Prediction:  real True Class:  real
# Test 157 Prediction:  real True Class:  real
# Test 158 Prediction:  real True Class:  real
# Test 159 Prediction:  real True Class:  real
# Test 160 Prediction:  real True Class:  real
# Test 161 Prediction:  real True Class:  real
# Test 162 Prediction:  real True Class:  real
# Test 163 Prediction:  real True Class:  real
# Test 164 Prediction:  fake True Class:  real
# Test 165 Prediction:  real True Class:  real
# Test 166 Prediction:  real True Class:  real
# Test 167 Prediction:  real True Class:  real
# Test 168 Prediction:  real True Class:  real
# Test 169 Prediction:  real True Class:  real
# Test 170 Prediction:  real True Class:  real
# Test 171 Prediction:  real True Class:  real
# Test 172 Prediction:  real True Class:  real
# Test 173 Prediction:  fake True Class:  real
# Test 174 Prediction:  real True Class:  real
# Test 175 Prediction:  real True Class:  real
# Test 176 Prediction:  real True Class:  real
# Test 177 Prediction:  real True Class:  real
# Test 178 Prediction:  real True Class:  real
# Test 179 Prediction:  real True Class:  real
# Test 180 Prediction:  real True Class:  real
# Test 181 Prediction:  real True Class:  real
# Test 182 Prediction:  real True Class:  real
# Test 183 Prediction:  real True Class:  real
# Test 184 Prediction:  real True Class:  real
# Test 185 Prediction:  real True Class:  real
# Test 186 Prediction:  real True Class:  real
# Test 187 Prediction:  real True Class:  real
# Test 188 Prediction:  real True Class:  real
# Test 189 Prediction:  real True Class:  real
# Test 190 Prediction:  real True Class:  real
# Test 191 Prediction:  real True Class:  real
# Test 192 Prediction:  real True Class:  real
# Test 193 Prediction:  real True Class:  real
# Test 194 Prediction:  real True Class:  real
# Test 195 Prediction:  real True Class:  real
# Test 196 Prediction:  real True Class:  real
# Test 197 Prediction:  real True Class:  real
# Test 198 Prediction:  real True Class:  real
# Test 199 Prediction:  real True Class:  real
# Test 200 Prediction:  real True Class:  real
# Test 201 Prediction:  real True Class:  real
# Test 202 Prediction:  real True Class:  real
# Test 203 Prediction:  real True Class:  real
# Test 204 Prediction:  real True Class:  real
# Test 205 Prediction:  real True Class:  real
# Test 206 Prediction:  real True Class:  real
# Test 207 Prediction:  real True Class:  real
# Test 208 Prediction:  real True Class:  real
# Test 209 Prediction:  real True Class:  real
# Test 210 Prediction:  real True Class:  real
# Test 211 Prediction:  real True Class:  real
# Test 212 Prediction:  real True Class:  real
# Test 213 Prediction:  real True Class:  real
# Test 214 Prediction:  real True Class:  real
# Test 215 Prediction:  real True Class:  real
# Test 216 Prediction:  real True Class:  real
# Test 217 Prediction:  real True Class:  real
# Test 218 Prediction:  real True Class:  real
# Test 219 Prediction:  real True Class:  real
# Test 220 Prediction:  real True Class:  real
# Test 221 Prediction:  real True Class:  real
# Test 222 Prediction:  real True Class:  real
# Test 223 Prediction:  real True Class:  real
# Test 224 Prediction:  real True Class:  real
# Test 225 Prediction:  real True Class:  real
# Test 226 Prediction:  real True Class:  real
# Test 227 Prediction:  real True Class:  real
# Test 228 Prediction:  real True Class:  real
# Test 229 Prediction:  real True Class:  real
# Test 230 Prediction:  real True Class:  real
# Test 231 Prediction:  real True Class:  real
# Test 232 Prediction:  real True Class:  real
# Test 233 Prediction:  real True Class:  real
# Test 234 Prediction:  real True Class:  real
# Test 235 Prediction:  real True Class:  real
# Test 236 Prediction:  real True Class:  real
# Test 237 Prediction:  real True Class:  real
# Test 238 Prediction:  real True Class:  real
# Test 239 Prediction:  real True Class:  real
# Test 240 Prediction:  real True Class:  real
# Test 241 Prediction:  real True Class:  real
# Test 242 Prediction:  real True Class:  real
# Test 243 Prediction:  fake True Class:  real
# Test 244 Prediction:  real True Class:  real
# Test 245 Prediction:  real True Class:  real
# Test 246 Prediction:  real True Class:  real
# Test 247 Prediction:  real True Class:  real
# Test 248 Prediction:  real True Class:  real
# Test 249 Prediction:  real True Class:  real
# Test 250 Prediction:  real True Class:  real
# Test 251 Prediction:  real True Class:  real
# Test 252 Prediction:  real True Class:  real
# Test 253 Prediction:  real True Class:  real
# Test 254 Prediction:  real True Class:  real
# Test 255 Prediction:  real True Class:  real
# Test 256 Prediction:  fake True Class:  fake
# Test 257 Prediction:  fake True Class:  fake
# Test 258 Prediction:  fake True Class:  fake
# Test 259 Prediction:  fake True Class:  fake
# Test 260 Prediction:  real True Class:  fake
# Test 261 Prediction:  fake True Class:  fake
# Test 262 Prediction:  fake True Class:  fake
# Test 263 Prediction:  real True Class:  fake
# Test 264 Prediction:  fake True Class:  fake
# Test 265 Prediction:  fake True Class:  fake
# Test 266 Prediction:  fake True Class:  fake
# Test 267 Prediction:  real True Class:  fake
# Test 268 Prediction:  real True Class:  fake
# Test 269 Prediction:  fake True Class:  fake
# Test 270 Prediction:  real True Class:  fake
# Test 271 Prediction:  fake True Class:  fake
# Test 272 Prediction:  fake True Class:  fake
# Test 273 Prediction:  fake True Class:  fake
# Test 274 Prediction:  real True Class:  fake
# Test 275 Prediction:  fake True Class:  fake
# Test 276 Prediction:  fake True Class:  fake
# Test 277 Prediction:  fake True Class:  fake
# Test 278 Prediction:  fake True Class:  fake
# Test 279 Prediction:  fake True Class:  fake
# Test 280 Prediction:  fake True Class:  fake
# Test 281 Prediction:  fake True Class:  fake
# Test 282 Prediction:  fake True Class:  fake
# Test 283 Prediction:  fake True Class:  fake
# Test 284 Prediction:  fake True Class:  fake
# Test 285 Prediction:  fake True Class:  fake
# Test 286 Prediction:  fake True Class:  fake
# Test 287 Prediction:  real True Class:  fake
# Test 288 Prediction:  fake True Class:  fake
# Test 289 Prediction:  real True Class:  fake
# Test 290 Prediction:  real True Class:  fake
# Test 291 Prediction:  fake True Class:  fake
# Test 292 Prediction:  fake True Class:  fake
# Test 293 Prediction:  fake True Class:  fake
# Test 294 Prediction:  fake True Class:  fake
# Test 295 Prediction:  fake True Class:  fake
# Test 296 Prediction:  fake True Class:  fake
# Test 297 Prediction:  fake True Class:  fake
# Test 298 Prediction:  real True Class:  fake
# Test 299 Prediction:  real True Class:  fake
# Test 300 Prediction:  fake True Class:  fake
# Test 301 Prediction:  fake True Class:  fake
# Test 302 Prediction:  real True Class:  fake
# Test 303 Prediction:  fake True Class:  fake
# Test 304 Prediction:  fake True Class:  fake
# Test 305 Prediction:  fake True Class:  fake
# Test 306 Prediction:  fake True Class:  fake
# Test 307 Prediction:  fake True Class:  fake
# Test 308 Prediction:  real True Class:  fake
# Test 309 Prediction:  fake True Class:  fake
# Test 310 Prediction:  real True Class:  fake
# Test 311 Prediction:  fake True Class:  fake
# Test 312 Prediction:  fake True Class:  fake
# Test 313 Prediction:  real True Class:  fake
# Test 314 Prediction:  fake True Class:  fake
# Test 315 Prediction:  fake True Class:  fake
# Test 316 Prediction:  fake True Class:  fake
# Test 317 Prediction:  fake True Class:  fake
# Test 318 Prediction:  fake True Class:  fake
# Test 319 Prediction:  fake True Class:  fake
# Test 320 Prediction:  fake True Class:  fake
# Test 321 Prediction:  fake True Class:  fake
# Test 322 Prediction:  fake True Class:  fake
# Test 323 Prediction:  fake True Class:  fake
# Test 324 Prediction:  fake True Class:  fake
# Test 325 Prediction:  fake True Class:  fake
# Test 326 Prediction:  fake True Class:  fake
# Test 327 Prediction:  fake True Class:  fake
# Test 328 Prediction:  real True Class:  fake
# Test 329 Prediction:  real True Class:  fake
# Test 330 Prediction:  fake True Class:  fake
# Test 331 Prediction:  fake True Class:  fake
# Test 332 Prediction:  fake True Class:  fake
# Test 333 Prediction:  fake True Class:  fake
# Test 334 Prediction:  fake True Class:  fake
# Test 335 Prediction:  fake True Class:  fake
# Test 336 Prediction:  fake True Class:  fake
# Test 337 Prediction:  fake True Class:  fake
# Test 338 Prediction:  fake True Class:  fake
# Test 339 Prediction:  real True Class:  fake
# Test 340 Prediction:  real True Class:  fake
# Test 341 Prediction:  fake True Class:  fake
# Test 342 Prediction:  fake True Class:  fake
# Test 343 Prediction:  fake True Class:  fake
# Test 344 Prediction:  real True Class:  fake
# Test 345 Prediction:  fake True Class:  fake
# Test 346 Prediction:  fake True Class:  fake
# Test 347 Prediction:  fake True Class:  fake
# Test 348 Prediction:  fake True Class:  fake
# Test 349 Prediction:  fake True Class:  fake
# Test 350 Prediction:  real True Class:  fake
# Test 351 Prediction:  real True Class:  fake
# Test 352 Prediction:  fake True Class:  fake
# Test 353 Prediction:  fake True Class:  fake
# Test 354 Prediction:  fake True Class:  fake
# Test 355 Prediction:  real True Class:  fake
# Test 356 Prediction:  fake True Class:  fake
# Test 357 Prediction:  real True Class:  fake
# Test 358 Prediction:  real True Class:  fake
# Test 359 Prediction:  real True Class:  fake
# Test 360 Prediction:  fake True Class:  fake
# Test 361 Prediction:  fake True Class:  fake
# Test 362 Prediction:  fake True Class:  fake
# Test 363 Prediction:  fake True Class:  fake
# Test 364 Prediction:  fake True Class:  fake
# Test 365 Prediction:  fake True Class:  fake
# Test 366 Prediction:  real True Class:  fake
# Test 367 Prediction:  fake True Class:  fake
# Test 368 Prediction:  fake True Class:  fake
# Test 369 Prediction:  fake True Class:  fake
# Test 370 Prediction:  fake True Class:  fake
# Test 371 Prediction:  fake True Class:  fake
# Test 372 Prediction:  real True Class:  fake
# Test 373 Prediction:  fake True Class:  fake
# Test 374 Prediction:  fake True Class:  fake
# Test 375 Prediction:  fake True Class:  fake
# Test 376 Prediction:  real True Class:  fake
# Test 377 Prediction:  fake True Class:  fake
# Test 378 Prediction:  fake True Class:  fake
# Test 379 Prediction:  fake True Class:  fake
# Test 380 Prediction:  real True Class:  fake
# Test 381 Prediction:  real True Class:  fake
# Test 382 Prediction:  fake True Class:  fake
# Test 383 Prediction:  fake True Class:  fake
# Test 384 Prediction:  fake True Class:  fake
# Test 385 Prediction:  fake True Class:  fake
# Test 386 Prediction:  fake True Class:  fake
# Test 387 Prediction:  fake True Class:  fake
# Test 388 Prediction:  real True Class:  fake
# Test 389 Prediction:  fake True Class:  fake
# Test 390 Prediction:  fake True Class:  fake
# Test 391 Prediction:  real True Class:  fake
# Test 392 Prediction:  fake True Class:  fake
# Test 393 Prediction:  fake True Class:  fake
# Test 394 Prediction:  fake True Class:  fake
# Test 395 Prediction:  fake True Class:  fake
# Test 396 Prediction:  fake True Class:  fake
# Test 397 Prediction:  fake True Class:  fake
# Test 398 Prediction:  real True Class:  fake
# Test 399 Prediction:  fake True Class:  fake
# Test 400 Prediction:  fake True Class:  fake
# Test 401 Prediction:  fake True Class:  fake
# Test 402 Prediction:  fake True Class:  fake
# Test 403 Prediction:  fake True Class:  fake
# Test 404 Prediction:  fake True Class:  fake
# Test 405 Prediction:  real True Class:  fake
# Test 406 Prediction:  fake True Class:  fake
# Test 407 Prediction:  real True Class:  fake
# Test 408 Prediction:  fake True Class:  fake
# Test 409 Prediction:  real True Class:  fake
# Test 410 Prediction:  fake True Class:  fake
# Test 411 Prediction:  fake True Class:  fake
# Test 412 Prediction:  fake True Class:  fake
# Test 413 Prediction:  real True Class:  fake
# Test 414 Prediction:  fake True Class:  fake
# Test 415 Prediction:  fake True Class:  fake
# Test 416 Prediction:  fake True Class:  fake
# Test 417 Prediction:  fake True Class:  fake
# Test 418 Prediction:  real True Class:  fake
# Test 419 Prediction:  fake True Class:  fake
# Test 420 Prediction:  fake True Class:  fake
# Test 421 Prediction:  fake True Class:  fake
# Test 422 Prediction:  fake True Class:  fake
# Test 423 Prediction:  fake True Class:  fake
# Test 424 Prediction:  fake True Class:  fake
# Test 425 Prediction:  fake True Class:  fake
# Test 426 Prediction:  fake True Class:  fake
# Test 427 Prediction:  fake True Class:  fake
# Test 428 Prediction:  fake True Class:  fake
# Test 429 Prediction:  fake True Class:  fake
# Test 430 Prediction:  fake True Class:  fake
# Test 431 Prediction:  real True Class:  fake
# Test 432 Prediction:  real True Class:  fake
# Test 433 Prediction:  real True Class:  fake
# Test 434 Prediction:  real True Class:  fake
# Test 435 Prediction:  fake True Class:  fake
# Test 436 Prediction:  fake True Class:  fake
# Test 437 Prediction:  real True Class:  fake
# Test 438 Prediction:  fake True Class:  fake
# Test 439 Prediction:  fake True Class:  fake
# Test 440 Prediction:  real True Class:  fake
# Test 441 Prediction:  fake True Class:  fake
# Test 442 Prediction:  fake True Class:  fake
# Test 443 Prediction:  fake True Class:  fake
# Test 444 Prediction:  fake True Class:  fake
# Test 445 Prediction:  fake True Class:  fake
# Test 446 Prediction:  fake True Class:  fake
# Test 447 Prediction:  fake True Class:  fake
# Test 448 Prediction:  fake True Class:  fake
# Test 449 Prediction:  fake True Class:  fake
# Test 450 Prediction:  fake True Class:  fake
# Test 451 Prediction:  real True Class:  fake
# Test 452 Prediction:  fake True Class:  fake
# Test 453 Prediction:  fake True Class:  fake
# Test 454 Prediction:  fake True Class:  fake
# Test 455 Prediction:  fake True Class:  fake
# Test 456 Prediction:  real True Class:  fake
# Test 457 Prediction:  fake True Class:  fake
# Test 458 Prediction:  fake True Class:  fake
# Test 459 Prediction:  fake True Class:  fake
# Test 460 Prediction:  fake True Class:  fake
# Test 461 Prediction:  fake True Class:  fake
# Test 462 Prediction:  real True Class:  fake
# Test 463 Prediction:  fake True Class:  fake
# Test 464 Prediction:  fake True Class:  fake
# Test 465 Prediction:  fake True Class:  fake
# Test 466 Prediction:  fake True Class:  fake
# Test 467 Prediction:  fake True Class:  fake
# Test 468 Prediction:  fake True Class:  fake
# Test 469 Prediction:  fake True Class:  fake
# Test 470 Prediction:  fake True Class:  fake
# Test 471 Prediction:  real True Class:  fake
# Test 472 Prediction:  fake True Class:  fake
# Test 473 Prediction:  fake True Class:  fake
# Test 474 Prediction:  real True Class:  fake
# Test 475 Prediction:  fake True Class:  fake
# Test 476 Prediction:  fake True Class:  fake
# Test 477 Prediction:  fake True Class:  fake
# Test 478 Prediction:  fake True Class:  fake
# Test 479 Prediction:  fake True Class:  fake
# Test 480 Prediction:  fake True Class:  fake
# Test 481 Prediction:  fake True Class:  fake
# Test 482 Prediction:  fake True Class:  fake
# Test 483 Prediction:  fake True Class:  fake
# Test 484 Prediction:  fake True Class:  fake
# Test 485 Prediction:  real True Class:  fake
# Test 486 Prediction:  fake True Class:  fake
# Test 487 Prediction:  fake True Class:  fake
# Test 488 Prediction:  fake True Class:  fake
# Test 489 Prediction:  fake True Class:  fake
# Test 490 Prediction:  fake True Class:  fake
# Test 491 Prediction:  fake True Class:  fake
# Test 492 Prediction:  real True Class:  fake
# Test 493 Prediction:  real True Class:  fake
# Test 494 Prediction:  fake True Class:  fake
# Test 495 Prediction:  fake True Class:  fake
# Test 496 Prediction:  fake True Class:  fake
# Test 497 Prediction:  fake True Class:  fake
# Test 498 Prediction:  real True Class:  fake
# Test 499 Prediction:  fake True Class:  fake
# Test 500 Prediction:  real True Class:  fake
# Test 501 Prediction:  fake True Class:  fake
# Test 502 Prediction:  real True Class:  fake
# Test 503 Prediction:  fake True Class:  fake
# Test 504 Prediction:  fake True Class:  fake
# Test 505 Prediction:  real True Class:  fake
# Test 506 Prediction:  fake True Class:  fake
# Test 507 Prediction:  fake True Class:  fake
# Test 508 Prediction:  fake True Class:  fake
# Test 509 Prediction:  fake True Class:  fake
# Test 510 Prediction:  fake True Class:  fake
# Test 511 Prediction:  real True Class:  fake
# Done!
# Accuracy:  0.86328125

# %% [markdown]
# ### Euclidean distances (L2 distances)
# #### the results are same!!!

# %%
#重置图（这个是为了用于多次运行）
tf.reset_default_graph()

#使用训练集数目为160条
#使用验证集（测试集）数目为80

xtr = tf.placeholder('float', [None, 4096])
xte = tf.placeholder('float', [4096])

#计算各个对应位置的距离（减法使用广播形式）
# L2 normalization
#distance = tf.norm(tf.abs(tf.subtract(xtr, xte)), axis=1, ord=2)
distance = tf.sqrt(tf.reduce_sum(tf.pow(tf.add(xtr,tf.negative(xte)),2),reduction_indices=1))

#寻找距离最近（即最相似的行所在位置）
pred = tf.arg_min(distance, 0)

accuracy = 0.

#初始化
init = tf.global_variables_initializer()


with tf.Session() as sess:
    sess.run(init)

    for i in range(len(codes2)):
        #计算最相近的所在行位置
        nn_index = sess.run(pred, feed_dict={xtr:codes, xte: codes2[i, :]})

        #取出测试集上最相近行对应的label与真是label对比
        print('Test', i, 'Prediction: ', labels[nn_index], \
               'True Class: ', labels2[i])
        if labels[nn_index] == labels2[i]:
            accuracy += 1./len(codes2)
    print('Done!')
    print('Accuracy: ', accuracy)
# Out:
# WARNING:tensorflow:From <ipython-input-33-ecf3a5a7c82f>:16: arg_min (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmin` instead
# Test 0 Prediction:  real True Class:  real
# Test 1 Prediction:  real True Class:  real
# Test 2 Prediction:  real True Class:  real
# Test 3 Prediction:  real True Class:  real
# Test 4 Prediction:  fake True Class:  real
# Test 5 Prediction:  real True Class:  real
# Test 6 Prediction:  real True Class:  real
# Test 7 Prediction:  real True Class:  real
# Test 8 Prediction:  real True Class:  real
# Test 9 Prediction:  real True Class:  real
# Test 10 Prediction:  real True Class:  real
# Test 11 Prediction:  fake True Class:  real
# Test 12 Prediction:  real True Class:  real
# Test 13 Prediction:  real True Class:  real
# Test 14 Prediction:  real True Class:  real
# Test 15 Prediction:  real True Class:  real
# Test 16 Prediction:  real True Class:  real
# Test 17 Prediction:  real True Class:  real
# Test 18 Prediction:  fake True Class:  real
# Test 19 Prediction:  real True Class:  real
# Test 20 Prediction:  real True Class:  real
# Test 21 Prediction:  real True Class:  real
# Test 22 Prediction:  real True Class:  real
# Test 23 Prediction:  real True Class:  real
# Test 24 Prediction:  real True Class:  real
# Test 25 Prediction:  real True Class:  real
# Test 26 Prediction:  real True Class:  real
# Test 27 Prediction:  real True Class:  real
# Test 28 Prediction:  real True Class:  real
# Test 29 Prediction:  real True Class:  real
# Test 30 Prediction:  real True Class:  real
# Test 31 Prediction:  real True Class:  real
# Test 32 Prediction:  real True Class:  real
# Test 33 Prediction:  real True Class:  real
# Test 34 Prediction:  real True Class:  real
# Test 35 Prediction:  real True Class:  real
# Test 36 Prediction:  real True Class:  real
# Test 37 Prediction:  real True Class:  real
# Test 38 Prediction:  real True Class:  real
# Test 39 Prediction:  real True Class:  real
# Test 40 Prediction:  real True Class:  real
# Test 41 Prediction:  real True Class:  real
# Test 42 Prediction:  real True Class:  real
# Test 43 Prediction:  real True Class:  real
# Test 44 Prediction:  real True Class:  real
# Test 45 Prediction:  real True Class:  real
# Test 46 Prediction:  real True Class:  real
# Test 47 Prediction:  real True Class:  real
# Test 48 Prediction:  real True Class:  real
# Test 49 Prediction:  real True Class:  real
# Test 50 Prediction:  real True Class:  real
# Test 51 Prediction:  real True Class:  real
# Test 52 Prediction:  real True Class:  real
# Test 53 Prediction:  real True Class:  real
# Test 54 Prediction:  real True Class:  real
# Test 55 Prediction:  real True Class:  real
# Test 56 Prediction:  real True Class:  real
# Test 57 Prediction:  real True Class:  real
# Test 58 Prediction:  real True Class:  real
# Test 59 Prediction:  fake True Class:  real
# Test 60 Prediction:  real True Class:  real
# Test 61 Prediction:  real True Class:  real
# Test 62 Prediction:  real True Class:  real
# Test 63 Prediction:  real True Class:  real
# Test 64 Prediction:  real True Class:  real
# Test 65 Prediction:  real True Class:  real
# Test 66 Prediction:  real True Class:  real
# Test 67 Prediction:  real True Class:  real
# Test 68 Prediction:  real True Class:  real
# Test 69 Prediction:  real True Class:  real
# Test 70 Prediction:  real True Class:  real
# Test 71 Prediction:  real True Class:  real
# Test 72 Prediction:  real True Class:  real
# Test 73 Prediction:  real True Class:  real
# Test 74 Prediction:  real True Class:  real
# Test 75 Prediction:  real True Class:  real
# Test 76 Prediction:  real True Class:  real
# Test 77 Prediction:  real True Class:  real
# Test 78 Prediction:  real True Class:  real
# Test 79 Prediction:  real True Class:  real
# Test 80 Prediction:  real True Class:  real
# Test 81 Prediction:  real True Class:  real
# Test 82 Prediction:  real True Class:  real
# Test 83 Prediction:  real True Class:  real
# Test 84 Prediction:  real True Class:  real
# Test 85 Prediction:  real True Class:  real
# Test 86 Prediction:  real True Class:  real
# Test 87 Prediction:  real True Class:  real
# Test 88 Prediction:  real True Class:  real
# Test 89 Prediction:  real True Class:  real
# Test 90 Prediction:  real True Class:  real
# Test 91 Prediction:  real True Class:  real
# Test 92 Prediction:  real True Class:  real
# Test 93 Prediction:  real True Class:  real
# Test 94 Prediction:  real True Class:  real
# Test 95 Prediction:  real True Class:  real
# Test 96 Prediction:  real True Class:  real
# Test 97 Prediction:  real True Class:  real
# Test 98 Prediction:  real True Class:  real
# Test 99 Prediction:  real True Class:  real
# Test 100 Prediction:  real True Class:  real
# Test 101 Prediction:  real True Class:  real
# Test 102 Prediction:  real True Class:  real
# Test 103 Prediction:  real True Class:  real
# Test 104 Prediction:  real True Class:  real
# Test 105 Prediction:  real True Class:  real
# Test 106 Prediction:  real True Class:  real
# Test 107 Prediction:  real True Class:  real
# Test 108 Prediction:  real True Class:  real
# Test 109 Prediction:  real True Class:  real
# Test 110 Prediction:  real True Class:  real
# Test 111 Prediction:  real True Class:  real
# Test 112 Prediction:  real True Class:  real
# Test 113 Prediction:  real True Class:  real
# Test 114 Prediction:  real True Class:  real
# Test 115 Prediction:  real True Class:  real
# Test 116 Prediction:  real True Class:  real
# Test 117 Prediction:  real True Class:  real
# Test 118 Prediction:  real True Class:  real
# Test 119 Prediction:  real True Class:  real
# Test 120 Prediction:  real True Class:  real
# Test 121 Prediction:  real True Class:  real
# Test 122 Prediction:  fake True Class:  real
# Test 123 Prediction:  real True Class:  real
# Test 124 Prediction:  real True Class:  real
# Test 125 Prediction:  real True Class:  real
# Test 126 Prediction:  real True Class:  real
# Test 127 Prediction:  real True Class:  real
# Test 128 Prediction:  fake True Class:  real
# Test 129 Prediction:  real True Class:  real
# Test 130 Prediction:  real True Class:  real
# Test 131 Prediction:  real True Class:  real
# Test 132 Prediction:  real True Class:  real
# Test 133 Prediction:  real True Class:  real
# Test 134 Prediction:  real True Class:  real
# Test 135 Prediction:  real True Class:  real
# Test 136 Prediction:  real True Class:  real
# Test 137 Prediction:  real True Class:  real
# Test 138 Prediction:  real True Class:  real
# Test 139 Prediction:  real True Class:  real
# Test 140 Prediction:  real True Class:  real
# Test 141 Prediction:  fake True Class:  real
# Test 142 Prediction:  real True Class:  real
# Test 143 Prediction:  real True Class:  real
# Test 144 Prediction:  real True Class:  real
# Test 145 Prediction:  real True Class:  real
# Test 146 Prediction:  real True Class:  real
# Test 147 Prediction:  real True Class:  real
# Test 148 Prediction:  real True Class:  real
# Test 149 Prediction:  real True Class:  real
# Test 150 Prediction:  real True Class:  real
# Test 151 Prediction:  real True Class:  real
# Test 152 Prediction:  real True Class:  real
# Test 153 Prediction:  real True Class:  real
# Test 154 Prediction:  real True Class:  real
# Test 155 Prediction:  fake True Class:  real
# Test 156 Prediction:  real True Class:  real
# Test 157 Prediction:  real True Class:  real
# Test 158 Prediction:  real True Class:  real
# Test 159 Prediction:  real True Class:  real
# Test 160 Prediction:  real True Class:  real
# Test 161 Prediction:  real True Class:  real
# Test 162 Prediction:  real True Class:  real
# Test 163 Prediction:  real True Class:  real
# Test 164 Prediction:  fake True Class:  real
# Test 165 Prediction:  real True Class:  real
# Test 166 Prediction:  real True Class:  real
# Test 167 Prediction:  real True Class:  real
# Test 168 Prediction:  real True Class:  real
# Test 169 Prediction:  real True Class:  real
# Test 170 Prediction:  real True Class:  real
# Test 171 Prediction:  real True Class:  real
# Test 172 Prediction:  real True Class:  real
# Test 173 Prediction:  fake True Class:  real
# Test 174 Prediction:  real True Class:  real
# Test 175 Prediction:  real True Class:  real
# Test 176 Prediction:  real True Class:  real
# Test 177 Prediction:  real True Class:  real
# Test 178 Prediction:  real True Class:  real
# Test 179 Prediction:  real True Class:  real
# Test 180 Prediction:  real True Class:  real
# Test 181 Prediction:  real True Class:  real
# Test 182 Prediction:  real True Class:  real
# Test 183 Prediction:  real True Class:  real
# Test 184 Prediction:  real True Class:  real
# Test 185 Prediction:  real True Class:  real
# Test 186 Prediction:  real True Class:  real
# Test 187 Prediction:  real True Class:  real
# Test 188 Prediction:  real True Class:  real
# Test 189 Prediction:  fake True Class:  real
# Test 190 Prediction:  real True Class:  real
# Test 191 Prediction:  real True Class:  real
# Test 192 Prediction:  real True Class:  real
# Test 193 Prediction:  real True Class:  real
# Test 194 Prediction:  real True Class:  real
# Test 195 Prediction:  real True Class:  real
# Test 196 Prediction:  real True Class:  real
# Test 197 Prediction:  real True Class:  real
# Test 198 Prediction:  real True Class:  real
# Test 199 Prediction:  real True Class:  real
# Test 200 Prediction:  real True Class:  real
# Test 201 Prediction:  real True Class:  real
# Test 202 Prediction:  real True Class:  real
# Test 203 Prediction:  real True Class:  real
# Test 204 Prediction:  real True Class:  real
# Test 205 Prediction:  real True Class:  real
# Test 206 Prediction:  real True Class:  real
# Test 207 Prediction:  real True Class:  real
# Test 208 Prediction:  real True Class:  real
# Test 209 Prediction:  real True Class:  real
# Test 210 Prediction:  real True Class:  real
# Test 211 Prediction:  real True Class:  real
# Test 212 Prediction:  real True Class:  real
# Test 213 Prediction:  real True Class:  real
# Test 214 Prediction:  real True Class:  real
# Test 215 Prediction:  real True Class:  real
# Test 216 Prediction:  real True Class:  real
# Test 217 Prediction:  real True Class:  real
# Test 218 Prediction:  real True Class:  real
# Test 219 Prediction:  real True Class:  real
# Test 220 Prediction:  real True Class:  real
# Test 221 Prediction:  real True Class:  real
# Test 222 Prediction:  real True Class:  real
# Test 223 Prediction:  real True Class:  real
# Test 224 Prediction:  real True Class:  real
# Test 225 Prediction:  real True Class:  real
# Test 226 Prediction:  real True Class:  real
# Test 227 Prediction:  real True Class:  real
# Test 228 Prediction:  real True Class:  real
# Test 229 Prediction:  real True Class:  real
# Test 230 Prediction:  real True Class:  real
# Test 231 Prediction:  real True Class:  real
# Test 232 Prediction:  real True Class:  real
# Test 233 Prediction:  real True Class:  real
# Test 234 Prediction:  real True Class:  real
# Test 235 Prediction:  real True Class:  real
# Test 236 Prediction:  real True Class:  real
# Test 237 Prediction:  real True Class:  real
# Test 238 Prediction:  real True Class:  real
# Test 239 Prediction:  real True Class:  real
# Test 240 Prediction:  real True Class:  real
# Test 241 Prediction:  real True Class:  real
# Test 242 Prediction:  real True Class:  real
# Test 243 Prediction:  fake True Class:  real
# Test 244 Prediction:  real True Class:  real
# Test 245 Prediction:  real True Class:  real
# Test 246 Prediction:  real True Class:  real
# Test 247 Prediction:  real True Class:  real
# Test 248 Prediction:  real True Class:  real
# Test 249 Prediction:  real True Class:  real
# Test 250 Prediction:  real True Class:  real
# Test 251 Prediction:  real True Class:  real
# Test 252 Prediction:  real True Class:  real
# Test 253 Prediction:  real True Class:  real
# Test 254 Prediction:  real True Class:  real
# Test 255 Prediction:  real True Class:  real
# Test 256 Prediction:  fake True Class:  fake
# Test 257 Prediction:  fake True Class:  fake
# Test 258 Prediction:  fake True Class:  fake
# Test 259 Prediction:  real True Class:  fake
# Test 260 Prediction:  real True Class:  fake
# Test 261 Prediction:  fake True Class:  fake
# Test 262 Prediction:  fake True Class:  fake
# Test 263 Prediction:  real True Class:  fake
# Test 264 Prediction:  fake True Class:  fake
# Test 265 Prediction:  fake True Class:  fake
# Test 266 Prediction:  fake True Class:  fake
# Test 267 Prediction:  real True Class:  fake
# Test 268 Prediction:  real True Class:  fake
# Test 269 Prediction:  fake True Class:  fake
# Test 270 Prediction:  real True Class:  fake
# Test 271 Prediction:  fake True Class:  fake
# Test 272 Prediction:  fake True Class:  fake
# Test 273 Prediction:  fake True Class:  fake
# Test 274 Prediction:  fake True Class:  fake
# Test 275 Prediction:  fake True Class:  fake
# Test 276 Prediction:  fake True Class:  fake
# Test 277 Prediction:  fake True Class:  fake
# Test 278 Prediction:  fake True Class:  fake
# Test 279 Prediction:  fake True Class:  fake
# Test 280 Prediction:  fake True Class:  fake
# Test 281 Prediction:  fake True Class:  fake
# Test 282 Prediction:  fake True Class:  fake
# Test 283 Prediction:  fake True Class:  fake
# Test 284 Prediction:  fake True Class:  fake
# Test 285 Prediction:  real True Class:  fake
# Test 286 Prediction:  fake True Class:  fake
# Test 287 Prediction:  real True Class:  fake
# Test 288 Prediction:  fake True Class:  fake
# Test 289 Prediction:  real True Class:  fake
# Test 290 Prediction:  real True Class:  fake
# Test 291 Prediction:  fake True Class:  fake
# Test 292 Prediction:  fake True Class:  fake
# Test 293 Prediction:  fake True Class:  fake
# Test 294 Prediction:  fake True Class:  fake
# Test 295 Prediction:  fake True Class:  fake
# Test 296 Prediction:  fake True Class:  fake
# Test 297 Prediction:  real True Class:  fake
# Test 298 Prediction:  real True Class:  fake
# Test 299 Prediction:  real True Class:  fake
# Test 300 Prediction:  fake True Class:  fake
# Test 301 Prediction:  fake True Class:  fake
# Test 302 Prediction:  real True Class:  fake
# Test 303 Prediction:  fake True Class:  fake
# Test 304 Prediction:  fake True Class:  fake
# Test 305 Prediction:  fake True Class:  fake
# Test 306 Prediction:  fake True Class:  fake
# Test 307 Prediction:  fake True Class:  fake
# Test 308 Prediction:  real True Class:  fake
# Test 309 Prediction:  fake True Class:  fake
# Test 310 Prediction:  real True Class:  fake
# Test 311 Prediction:  fake True Class:  fake
# Test 312 Prediction:  fake True Class:  fake
# Test 313 Prediction:  real True Class:  fake
# Test 314 Prediction:  fake True Class:  fake
# Test 315 Prediction:  fake True Class:  fake
# Test 316 Prediction:  fake True Class:  fake
# Test 317 Prediction:  fake True Class:  fake
# Test 318 Prediction:  fake True Class:  fake
# Test 319 Prediction:  fake True Class:  fake
# Test 320 Prediction:  fake True Class:  fake
# Test 321 Prediction:  fake True Class:  fake
# Test 322 Prediction:  fake True Class:  fake
# Test 323 Prediction:  fake True Class:  fake
# Test 324 Prediction:  fake True Class:  fake
# Test 325 Prediction:  fake True Class:  fake
# Test 326 Prediction:  fake True Class:  fake
# Test 327 Prediction:  fake True Class:  fake
# Test 328 Prediction:  real True Class:  fake
# Test 329 Prediction:  fake True Class:  fake
# Test 330 Prediction:  fake True Class:  fake
# Test 331 Prediction:  fake True Class:  fake
# Test 332 Prediction:  fake True Class:  fake
# Test 333 Prediction:  fake True Class:  fake
# Test 334 Prediction:  fake True Class:  fake
# Test 335 Prediction:  fake True Class:  fake
# Test 336 Prediction:  fake True Class:  fake
# Test 337 Prediction:  fake True Class:  fake
# Test 338 Prediction:  fake True Class:  fake
# Test 339 Prediction:  real True Class:  fake
# Test 340 Prediction:  real True Class:  fake
# Test 341 Prediction:  fake True Class:  fake
# Test 342 Prediction:  fake True Class:  fake
# Test 343 Prediction:  fake True Class:  fake
# Test 344 Prediction:  fake True Class:  fake
# Test 345 Prediction:  fake True Class:  fake
# Test 346 Prediction:  fake True Class:  fake
# Test 347 Prediction:  fake True Class:  fake
# Test 348 Prediction:  fake True Class:  fake
# Test 349 Prediction:  fake True Class:  fake
# Test 350 Prediction:  real True Class:  fake
# Test 351 Prediction:  real True Class:  fake
# Test 352 Prediction:  fake True Class:  fake
# Test 353 Prediction:  fake True Class:  fake
# Test 354 Prediction:  fake True Class:  fake
# Test 355 Prediction:  real True Class:  fake
# Test 356 Prediction:  fake True Class:  fake
# Test 357 Prediction:  real True Class:  fake
# Test 358 Prediction:  real True Class:  fake
# Test 359 Prediction:  real True Class:  fake
# Test 360 Prediction:  fake True Class:  fake
# Test 361 Prediction:  fake True Class:  fake
# Test 362 Prediction:  fake True Class:  fake
# Test 363 Prediction:  fake True Class:  fake
# Test 364 Prediction:  fake True Class:  fake
# Test 365 Prediction:  fake True Class:  fake
# Test 366 Prediction:  real True Class:  fake
# Test 367 Prediction:  fake True Class:  fake
# Test 368 Prediction:  fake True Class:  fake
# Test 369 Prediction:  fake True Class:  fake
# Test 370 Prediction:  fake True Class:  fake
# Test 371 Prediction:  fake True Class:  fake
# Test 372 Prediction:  fake True Class:  fake
# Test 373 Prediction:  fake True Class:  fake
# Test 374 Prediction:  fake True Class:  fake
# Test 375 Prediction:  fake True Class:  fake
# Test 376 Prediction:  real True Class:  fake
# Test 377 Prediction:  fake True Class:  fake
# Test 378 Prediction:  fake True Class:  fake
# Test 379 Prediction:  fake True Class:  fake
# Test 380 Prediction:  real True Class:  fake
# Test 381 Prediction:  real True Class:  fake
# Test 382 Prediction:  fake True Class:  fake
# Test 383 Prediction:  fake True Class:  fake
# Test 384 Prediction:  fake True Class:  fake
# Test 385 Prediction:  fake True Class:  fake
# Test 386 Prediction:  fake True Class:  fake
# Test 387 Prediction:  fake True Class:  fake
# Test 388 Prediction:  real True Class:  fake
# Test 389 Prediction:  fake True Class:  fake
# Test 390 Prediction:  fake True Class:  fake
# Test 391 Prediction:  real True Class:  fake
# Test 392 Prediction:  fake True Class:  fake
# Test 393 Prediction:  fake True Class:  fake
# Test 394 Prediction:  fake True Class:  fake
# Test 395 Prediction:  fake True Class:  fake
# Test 396 Prediction:  fake True Class:  fake
# Test 397 Prediction:  fake True Class:  fake
# Test 398 Prediction:  real True Class:  fake
# Test 399 Prediction:  fake True Class:  fake
# Test 400 Prediction:  fake True Class:  fake
# Test 401 Prediction:  fake True Class:  fake
# Test 402 Prediction:  fake True Class:  fake
# Test 403 Prediction:  fake True Class:  fake
# Test 404 Prediction:  fake True Class:  fake
# Test 405 Prediction:  real True Class:  fake
# Test 406 Prediction:  fake True Class:  fake
# Test 407 Prediction:  real True Class:  fake
# Test 408 Prediction:  fake True Class:  fake
# Test 409 Prediction:  real True Class:  fake
# Test 410 Prediction:  fake True Class:  fake
# Test 411 Prediction:  fake True Class:  fake
# Test 412 Prediction:  fake True Class:  fake
# Test 413 Prediction:  fake True Class:  fake
# Test 414 Prediction:  fake True Class:  fake
# Test 415 Prediction:  fake True Class:  fake
# Test 416 Prediction:  fake True Class:  fake
# Test 417 Prediction:  fake True Class:  fake
# Test 418 Prediction:  real True Class:  fake
# Test 419 Prediction:  fake True Class:  fake
# Test 420 Prediction:  fake True Class:  fake
# Test 421 Prediction:  fake True Class:  fake
# Test 422 Prediction:  fake True Class:  fake
# Test 423 Prediction:  fake True Class:  fake
# Test 424 Prediction:  fake True Class:  fake
# Test 425 Prediction:  fake True Class:  fake
# Test 426 Prediction:  fake True Class:  fake
# Test 427 Prediction:  fake True Class:  fake
# Test 428 Prediction:  fake True Class:  fake
# Test 429 Prediction:  fake True Class:  fake
# Test 430 Prediction:  fake True Class:  fake
# Test 431 Prediction:  real True Class:  fake
# Test 432 Prediction:  real True Class:  fake
# Test 433 Prediction:  real True Class:  fake
# Test 434 Prediction:  real True Class:  fake
# Test 435 Prediction:  fake True Class:  fake
# Test 436 Prediction:  fake True Class:  fake
# Test 437 Prediction:  real True Class:  fake
# Test 438 Prediction:  real True Class:  fake
# Test 439 Prediction:  fake True Class:  fake
# Test 440 Prediction:  fake True Class:  fake
# Test 441 Prediction:  fake True Class:  fake
# Test 442 Prediction:  fake True Class:  fake
# Test 443 Prediction:  fake True Class:  fake
# Test 444 Prediction:  fake True Class:  fake
# Test 445 Prediction:  fake True Class:  fake
# Test 446 Prediction:  fake True Class:  fake
# Test 447 Prediction:  real True Class:  fake
# Test 448 Prediction:  fake True Class:  fake
# Test 449 Prediction:  fake True Class:  fake
# Test 450 Prediction:  fake True Class:  fake
# Test 451 Prediction:  real True Class:  fake
# Test 452 Prediction:  fake True Class:  fake
# Test 453 Prediction:  fake True Class:  fake
# Test 454 Prediction:  real True Class:  fake
# Test 455 Prediction:  fake True Class:  fake
# Test 456 Prediction:  real True Class:  fake
# Test 457 Prediction:  fake True Class:  fake
# Test 458 Prediction:  fake True Class:  fake
# Test 459 Prediction:  fake True Class:  fake
# Test 460 Prediction:  fake True Class:  fake
# Test 461 Prediction:  fake True Class:  fake
# Test 462 Prediction:  real True Class:  fake
# Test 463 Prediction:  fake True Class:  fake
# Test 464 Prediction:  fake True Class:  fake
# Test 465 Prediction:  fake True Class:  fake
# Test 466 Prediction:  fake True Class:  fake
# Test 467 Prediction:  fake True Class:  fake
# Test 468 Prediction:  fake True Class:  fake
# Test 469 Prediction:  fake True Class:  fake
# Test 470 Prediction:  fake True Class:  fake
# Test 471 Prediction:  real True Class:  fake
# Test 472 Prediction:  fake True Class:  fake
# Test 473 Prediction:  fake True Class:  fake
# Test 474 Prediction:  real True Class:  fake
# Test 475 Prediction:  fake True Class:  fake
# Test 476 Prediction:  fake True Class:  fake
# Test 477 Prediction:  fake True Class:  fake
# Test 478 Prediction:  fake True Class:  fake
# Test 479 Prediction:  fake True Class:  fake
# Test 480 Prediction:  fake True Class:  fake
# Test 481 Prediction:  fake True Class:  fake
# Test 482 Prediction:  fake True Class:  fake
# Test 483 Prediction:  fake True Class:  fake
# Test 484 Prediction:  real True Class:  fake
# Test 485 Prediction:  real True Class:  fake
# Test 486 Prediction:  fake True Class:  fake
# Test 487 Prediction:  fake True Class:  fake
# Test 488 Prediction:  fake True Class:  fake
# Test 489 Prediction:  fake True Class:  fake
# Test 490 Prediction:  fake True Class:  fake
# Test 491 Prediction:  fake True Class:  fake
# Test 492 Prediction:  real True Class:  fake
# Test 493 Prediction:  real True Class:  fake
# Test 494 Prediction:  fake True Class:  fake
# Test 495 Prediction:  fake True Class:  fake
# Test 496 Prediction:  fake True Class:  fake
# Test 497 Prediction:  fake True Class:  fake
# Test 498 Prediction:  real True Class:  fake
# Test 499 Prediction:  fake True Class:  fake
# Test 500 Prediction:  real True Class:  fake
# Test 501 Prediction:  fake True Class:  fake
# Test 502 Prediction:  real True Class:  fake
# Test 503 Prediction:  fake True Class:  fake
# Test 504 Prediction:  fake True Class:  fake
# Test 505 Prediction:  real True Class:  fake
# Test 506 Prediction:  fake True Class:  fake
# Test 507 Prediction:  fake True Class:  fake
# Test 508 Prediction:  fake True Class:  fake
# Test 509 Prediction:  fake True Class:  fake
# Test 510 Prediction:  fake True Class:  fake
# Test 511 Prediction:  real True Class:  fake
# Done!
# Accuracy:  0.861328125

# %% [markdown]
# ## Try use different K, use K=3, and select majority of the Class

# %%
def get_variables(xtr, xte):
    
    # calculate the distance
    distance = tf.reduce_sum(tf.abs(tf.subtract(xtr, xte)), reduction_indices=1)
    
    # change it to neg, because tf.nn.top returns the max value.
    neg_one = tf.constant(-1.0)
    neg_distances = tf.multiply(distance, neg_one)
    
    # get the indices
    vals, indx = tf.nn.top_k(neg_distances, k=3)
    return {'vals':vals,'indx':indx}

# %%
def get_majorirty_vote(idxlst):
    dic = {}
    dic['real'] = 0
    dic['fake'] = 0
    
    for i in idxlst:
        ss = labels[i]  
        dic[ss] += 1
    
    if dic['real'] >= dic['fake']:
        return 'real'
    else:
        return 'fake'

# %%
#重置图（这个是为了用于多次运行）
tf.reset_default_graph()

xtr = tf.placeholder('float', [None, 4096])
xte = tf.placeholder('float', [4096])

out = get_variables(xtr, xte)

accuracy = 0.

#初始化
init = tf.global_variables_initializer()


with tf.Session() as sess:
    sess.run(init)

    for i in range(len(codes2)):
        #计算最相近的所在行位置
        idx = sess.run(out['indx'], feed_dict={xtr:codes, xte: codes2[i, :]})
        
        #print(idx)
        #print('idx ?????-> ', idx[0])
        
        # 取 training set 中最近的 k 个，然后返回它们的 majority vote
        majority_vote_label = get_majorirty_vote(idx)
        print('Test', i, 'Prediction: ', majority_vote_label, \
             'True Class: ', labels2[i])
        
        if majority_vote_label == labels2[i]:
            accuracy += 1./len(codes2)
    
    print('Done!')
    print('Accuracy: ', accuracy)
# Out:
# Test 0 Prediction:  real True Class:  real
# Test 1 Prediction:  real True Class:  real
# Test 2 Prediction:  real True Class:  real
# Test 3 Prediction:  real True Class:  real
# Test 4 Prediction:  fake True Class:  real
# Test 5 Prediction:  real True Class:  real
# Test 6 Prediction:  real True Class:  real
# Test 7 Prediction:  real True Class:  real
# Test 8 Prediction:  real True Class:  real
# Test 9 Prediction:  real True Class:  real
# Test 10 Prediction:  real True Class:  real
# Test 11 Prediction:  real True Class:  real
# Test 12 Prediction:  real True Class:  real
# Test 13 Prediction:  real True Class:  real
# Test 14 Prediction:  real True Class:  real
# Test 15 Prediction:  real True Class:  real
# Test 16 Prediction:  real True Class:  real
# Test 17 Prediction:  real True Class:  real
# Test 18 Prediction:  real True Class:  real
# Test 19 Prediction:  real True Class:  real
# Test 20 Prediction:  real True Class:  real
# Test 21 Prediction:  real True Class:  real
# Test 22 Prediction:  real True Class:  real
# Test 23 Prediction:  real True Class:  real
# Test 24 Prediction:  real True Class:  real
# Test 25 Prediction:  real True Class:  real
# Test 26 Prediction:  real True Class:  real
# Test 27 Prediction:  real True Class:  real
# Test 28 Prediction:  real True Class:  real
# Test 29 Prediction:  real True Class:  real
# Test 30 Prediction:  real True Class:  real
# Test 31 Prediction:  real True Class:  real
# Test 32 Prediction:  real True Class:  real
# Test 33 Prediction:  real True Class:  real
# Test 34 Prediction:  real True Class:  real
# Test 35 Prediction:  real True Class:  real
# Test 36 Prediction:  real True Class:  real
# Test 37 Prediction:  real True Class:  real
# Test 38 Prediction:  real True Class:  real
# Test 39 Prediction:  real True Class:  real
# Test 40 Prediction:  real True Class:  real
# Test 41 Prediction:  fake True Class:  real
# Test 42 Prediction:  real True Class:  real
# Test 43 Prediction:  real True Class:  real
# Test 44 Prediction:  real True Class:  real
# Test 45 Prediction:  real True Class:  real
# Test 46 Prediction:  real True Class:  real
# Test 47 Prediction:  real True Class:  real
# Test 48 Prediction:  real True Class:  real
# Test 49 Prediction:  real True Class:  real
# Test 50 Prediction:  real True Class:  real
# Test 51 Prediction:  real True Class:  real
# Test 52 Prediction:  real True Class:  real
# Test 53 Prediction:  real True Class:  real
# Test 54 Prediction:  real True Class:  real
# Test 55 Prediction:  real True Class:  real
# Test 56 Prediction:  real True Class:  real
# Test 57 Prediction:  real True Class:  real
# Test 58 Prediction:  real True Class:  real
# Test 59 Prediction:  real True Class:  real
# Test 60 Prediction:  real True Class:  real
# Test 61 Prediction:  real True Class:  real
# Test 62 Prediction:  real True Class:  real
# Test 63 Prediction:  real True Class:  real
# Test 64 Prediction:  real True Class:  real
# Test 65 Prediction:  real True Class:  real
# Test 66 Prediction:  real True Class:  real
# Test 67 Prediction:  real True Class:  real
# Test 68 Prediction:  real True Class:  real
# Test 69 Prediction:  real True Class:  real
# Test 70 Prediction:  real True Class:  real
# Test 71 Prediction:  real True Class:  real
# Test 72 Prediction:  real True Class:  real
# Test 73 Prediction:  real True Class:  real
# Test 74 Prediction:  real True Class:  real
# Test 75 Prediction:  real True Class:  real
# Test 76 Prediction:  real True Class:  real
# Test 77 Prediction:  real True Class:  real
# Test 78 Prediction:  real True Class:  real
# Test 79 Prediction:  real True Class:  real
# Test 80 Prediction:  real True Class:  real
# Test 81 Prediction:  real True Class:  real
# Test 82 Prediction:  real True Class:  real
# Test 83 Prediction:  real True Class:  real
# Test 84 Prediction:  real True Class:  real
# Test 85 Prediction:  real True Class:  real
# Test 86 Prediction:  real True Class:  real
# Test 87 Prediction:  real True Class:  real
# Test 88 Prediction:  real True Class:  real
# Test 89 Prediction:  real True Class:  real
# Test 90 Prediction:  real True Class:  real
# Test 91 Prediction:  real True Class:  real
# Test 92 Prediction:  real True Class:  real
# Test 93 Prediction:  real True Class:  real
# Test 94 Prediction:  real True Class:  real
# Test 95 Prediction:  real True Class:  real
# Test 96 Prediction:  real True Class:  real
# Test 97 Prediction:  real True Class:  real
# Test 98 Prediction:  real True Class:  real
# Test 99 Prediction:  real True Class:  real
# Test 100 Prediction:  real True Class:  real
# Test 101 Prediction:  real True Class:  real
# Test 102 Prediction:  real True Class:  real
# Test 103 Prediction:  real True Class:  real
# Test 104 Prediction:  real True Class:  real
# Test 105 Prediction:  real True Class:  real
# Test 106 Prediction:  real True Class:  real
# Test 107 Prediction:  real True Class:  real
# Test 108 Prediction:  real True Class:  real
# Test 109 Prediction:  real True Class:  real
# Test 110 Prediction:  real True Class:  real
# Test 111 Prediction:  real True Class:  real
# Test 112 Prediction:  real True Class:  real
# Test 113 Prediction:  real True Class:  real
# Test 114 Prediction:  real True Class:  real
# Test 115 Prediction:  real True Class:  real
# Test 116 Prediction:  real True Class:  real
# Test 117 Prediction:  real True Class:  real
# Test 118 Prediction:  real True Class:  real
# Test 119 Prediction:  real True Class:  real
# Test 120 Prediction:  real True Class:  real
# Test 121 Prediction:  real True Class:  real
# Test 122 Prediction:  real True Class:  real
# Test 123 Prediction:  real True Class:  real
# Test 124 Prediction:  real True Class:  real
# Test 125 Prediction:  real True Class:  real
# Test 126 Prediction:  real True Class:  real
# Test 127 Prediction:  real True Class:  real
# Test 128 Prediction:  real True Class:  real
# Test 129 Prediction:  real True Class:  real
# Test 130 Prediction:  real True Class:  real
# Test 131 Prediction:  real True Class:  real
# Test 132 Prediction:  real True Class:  real
# Test 133 Prediction:  real True Class:  real
# Test 134 Prediction:  real True Class:  real
# Test 135 Prediction:  real True Class:  real
# Test 136 Prediction:  real True Class:  real
# Test 137 Prediction:  real True Class:  real
# Test 138 Prediction:  real True Class:  real
# Test 139 Prediction:  real True Class:  real
# Test 140 Prediction:  real True Class:  real
# Test 141 Prediction:  real True Class:  real
# Test 142 Prediction:  real True Class:  real
# Test 143 Prediction:  real True Class:  real
# Test 144 Prediction:  real True Class:  real
# Test 145 Prediction:  real True Class:  real
# Test 146 Prediction:  real True Class:  real
# Test 147 Prediction:  real True Class:  real
# Test 148 Prediction:  real True Class:  real
# Test 149 Prediction:  real True Class:  real
# Test 150 Prediction:  real True Class:  real
# Test 151 Prediction:  real True Class:  real
# Test 152 Prediction:  real True Class:  real
# Test 153 Prediction:  real True Class:  real
# Test 154 Prediction:  real True Class:  real
# Test 155 Prediction:  real True Class:  real
# Test 156 Prediction:  real True Class:  real
# Test 157 Prediction:  real True Class:  real
# Test 158 Prediction:  real True Class:  real
# Test 159 Prediction:  real True Class:  real
# Test 160 Prediction:  real True Class:  real
# Test 161 Prediction:  real True Class:  real
# Test 162 Prediction:  fake True Class:  real
# Test 163 Prediction:  real True Class:  real
# Test 164 Prediction:  fake True Class:  real
# Test 165 Prediction:  real True Class:  real
# Test 166 Prediction:  real True Class:  real
# Test 167 Prediction:  real True Class:  real
# Test 168 Prediction:  real True Class:  real
# Test 169 Prediction:  real True Class:  real
# Test 170 Prediction:  real True Class:  real
# Test 171 Prediction:  real True Class:  real
# Test 172 Prediction:  real True Class:  real
# Test 173 Prediction:  real True Class:  real
# Test 174 Prediction:  real True Class:  real
# Test 175 Prediction:  real True Class:  real
# Test 176 Prediction:  real True Class:  real
# Test 177 Prediction:  real True Class:  real
# Test 178 Prediction:  real True Class:  real
# Test 179 Prediction:  real True Class:  real
# Test 180 Prediction:  real True Class:  real
# Test 181 Prediction:  real True Class:  real
# Test 182 Prediction:  real True Class:  real
# Test 183 Prediction:  real True Class:  real
# Test 184 Prediction:  real True Class:  real
# Test 185 Prediction:  real True Class:  real
# Test 186 Prediction:  real True Class:  real
# Test 187 Prediction:  real True Class:  real
# Test 188 Prediction:  real True Class:  real
# Test 189 Prediction:  fake True Class:  real
# Test 190 Prediction:  real True Class:  real
# Test 191 Prediction:  real True Class:  real
# Test 192 Prediction:  real True Class:  real
# Test 193 Prediction:  real True Class:  real
# Test 194 Prediction:  real True Class:  real
# Test 195 Prediction:  real True Class:  real
# Test 196 Prediction:  real True Class:  real
# Test 197 Prediction:  real True Class:  real
# Test 198 Prediction:  real True Class:  real
# Test 199 Prediction:  real True Class:  real
# Test 200 Prediction:  real True Class:  real
# Test 201 Prediction:  real True Class:  real
# Test 202 Prediction:  real True Class:  real
# Test 203 Prediction:  real True Class:  real
# Test 204 Prediction:  real True Class:  real
# Test 205 Prediction:  real True Class:  real
# Test 206 Prediction:  real True Class:  real
# Test 207 Prediction:  real True Class:  real
# Test 208 Prediction:  real True Class:  real
# Test 209 Prediction:  real True Class:  real
# Test 210 Prediction:  real True Class:  real
# Test 211 Prediction:  real True Class:  real
# Test 212 Prediction:  real True Class:  real
# Test 213 Prediction:  real True Class:  real
# Test 214 Prediction:  real True Class:  real
# Test 215 Prediction:  real True Class:  real
# Test 216 Prediction:  real True Class:  real
# Test 217 Prediction:  real True Class:  real
# Test 218 Prediction:  real True Class:  real
# Test 219 Prediction:  real True Class:  real
# Test 220 Prediction:  real True Class:  real
# Test 221 Prediction:  real True Class:  real
# Test 222 Prediction:  real True Class:  real
# Test 223 Prediction:  real True Class:  real
# Test 224 Prediction:  real True Class:  real
# Test 225 Prediction:  real True Class:  real
# Test 226 Prediction:  real True Class:  real
# Test 227 Prediction:  real True Class:  real
# Test 228 Prediction:  real True Class:  real
# Test 229 Prediction:  real True Class:  real
# Test 230 Prediction:  real True Class:  real
# Test 231 Prediction:  real True Class:  real
# Test 232 Prediction:  real True Class:  real
# Test 233 Prediction:  real True Class:  real
# Test 234 Prediction:  real True Class:  real
# Test 235 Prediction:  real True Class:  real
# Test 236 Prediction:  real True Class:  real
# Test 237 Prediction:  real True Class:  real
# Test 238 Prediction:  real True Class:  real
# Test 239 Prediction:  real True Class:  real
# Test 240 Prediction:  real True Class:  real
# Test 241 Prediction:  real True Class:  real
# Test 242 Prediction:  real True Class:  real
# Test 243 Prediction:  fake True Class:  real
# Test 244 Prediction:  real True Class:  real
# Test 245 Prediction:  real True Class:  real
# Test 246 Prediction:  real True Class:  real
# Test 247 Prediction:  real True Class:  real
# Test 248 Prediction:  real True Class:  real
# Test 249 Prediction:  real True Class:  real
# Test 250 Prediction:  real True Class:  real
# Test 251 Prediction:  real True Class:  real
# Test 252 Prediction:  real True Class:  real
# Test 253 Prediction:  real True Class:  real
# Test 254 Prediction:  real True Class:  real
# Test 255 Prediction:  real True Class:  real
# Test 256 Prediction:  fake True Class:  fake
# Test 257 Prediction:  fake True Class:  fake
# Test 258 Prediction:  fake True Class:  fake
# Test 259 Prediction:  real True Class:  fake
# Test 260 Prediction:  fake True Class:  fake
# Test 261 Prediction:  fake True Class:  fake
# Test 262 Prediction:  fake True Class:  fake
# Test 263 Prediction:  real True Class:  fake
# Test 264 Prediction:  fake True Class:  fake
# Test 265 Prediction:  fake True Class:  fake
# Test 266 Prediction:  fake True Class:  fake
# Test 267 Prediction:  real True Class:  fake
# Test 268 Prediction:  real True Class:  fake
# Test 269 Prediction:  fake True Class:  fake
# Test 270 Prediction:  real True Class:  fake
# Test 271 Prediction:  fake True Class:  fake
# Test 272 Prediction:  fake True Class:  fake
# Test 273 Prediction:  fake True Class:  fake
# Test 274 Prediction:  fake True Class:  fake
# Test 275 Prediction:  fake True Class:  fake
# Test 276 Prediction:  fake True Class:  fake
# Test 277 Prediction:  fake True Class:  fake
# Test 278 Prediction:  fake True Class:  fake
# Test 279 Prediction:  fake True Class:  fake
# Test 280 Prediction:  real True Class:  fake
# Test 281 Prediction:  fake True Class:  fake
# Test 282 Prediction:  fake True Class:  fake
# Test 283 Prediction:  real True Class:  fake
# Test 284 Prediction:  fake True Class:  fake
# Test 285 Prediction:  real True Class:  fake
# Test 286 Prediction:  fake True Class:  fake
# Test 287 Prediction:  real True Class:  fake
# Test 288 Prediction:  real True Class:  fake
# Test 289 Prediction:  fake True Class:  fake
# Test 290 Prediction:  real True Class:  fake
# Test 291 Prediction:  fake True Class:  fake
# Test 292 Prediction:  fake True Class:  fake
# Test 293 Prediction:  fake True Class:  fake
# Test 294 Prediction:  fake True Class:  fake
# Test 295 Prediction:  fake True Class:  fake
# Test 296 Prediction:  fake True Class:  fake
# Test 297 Prediction:  real True Class:  fake
# Test 298 Prediction:  real True Class:  fake
# Test 299 Prediction:  real True Class:  fake
# Test 300 Prediction:  fake True Class:  fake
# Test 301 Prediction:  fake True Class:  fake
# Test 302 Prediction:  real True Class:  fake
# Test 303 Prediction:  fake True Class:  fake
# Test 304 Prediction:  fake True Class:  fake
# Test 305 Prediction:  fake True Class:  fake
# Test 306 Prediction:  fake True Class:  fake
# Test 307 Prediction:  fake True Class:  fake
# Test 308 Prediction:  real True Class:  fake
# Test 309 Prediction:  fake True Class:  fake
# Test 310 Prediction:  real True Class:  fake
# Test 311 Prediction:  real True Class:  fake
# Test 312 Prediction:  fake True Class:  fake
# Test 313 Prediction:  fake True Class:  fake
# Test 314 Prediction:  fake True Class:  fake
# Test 315 Prediction:  real True Class:  fake
# Test 316 Prediction:  fake True Class:  fake
# Test 317 Prediction:  fake True Class:  fake
# Test 318 Prediction:  fake True Class:  fake
# Test 319 Prediction:  fake True Class:  fake
# Test 320 Prediction:  fake True Class:  fake
# Test 321 Prediction:  real True Class:  fake
# Test 322 Prediction:  fake True Class:  fake
# Test 323 Prediction:  fake True Class:  fake
# Test 324 Prediction:  fake True Class:  fake
# Test 325 Prediction:  fake True Class:  fake
# Test 326 Prediction:  fake True Class:  fake
# Test 327 Prediction:  fake True Class:  fake
# Test 328 Prediction:  fake True Class:  fake
# Test 329 Prediction:  fake True Class:  fake
# Test 330 Prediction:  fake True Class:  fake
# Test 331 Prediction:  fake True Class:  fake
# Test 332 Prediction:  real True Class:  fake
# Test 333 Prediction:  real True Class:  fake
# Test 334 Prediction:  fake True Class:  fake
# Test 335 Prediction:  fake True Class:  fake
# Test 336 Prediction:  fake True Class:  fake
# Test 337 Prediction:  fake True Class:  fake
# Test 338 Prediction:  fake True Class:  fake
# Test 339 Prediction:  real True Class:  fake
# Test 340 Prediction:  real True Class:  fake
# Test 341 Prediction:  fake True Class:  fake
# Test 342 Prediction:  fake True Class:  fake
# Test 343 Prediction:  fake True Class:  fake
# Test 344 Prediction:  real True Class:  fake
# Test 345 Prediction:  fake True Class:  fake
# Test 346 Prediction:  fake True Class:  fake
# Test 347 Prediction:  fake True Class:  fake
# Test 348 Prediction:  fake True Class:  fake
# Test 349 Prediction:  fake True Class:  fake
# Test 350 Prediction:  real True Class:  fake
# Test 351 Prediction:  real True Class:  fake
# Test 352 Prediction:  fake True Class:  fake
# Test 353 Prediction:  fake True Class:  fake
# Test 354 Prediction:  fake True Class:  fake
# Test 355 Prediction:  real True Class:  fake
# Test 356 Prediction:  fake True Class:  fake
# Test 357 Prediction:  real True Class:  fake
# Test 358 Prediction:  real True Class:  fake
# Test 359 Prediction:  fake True Class:  fake
# Test 360 Prediction:  real True Class:  fake
# Test 361 Prediction:  fake True Class:  fake
# Test 362 Prediction:  fake True Class:  fake
# Test 363 Prediction:  fake True Class:  fake
# Test 364 Prediction:  fake True Class:  fake
# Test 365 Prediction:  fake True Class:  fake
# Test 366 Prediction:  real True Class:  fake
# Test 367 Prediction:  fake True Class:  fake
# Test 368 Prediction:  real True Class:  fake
# Test 369 Prediction:  fake True Class:  fake
# Test 370 Prediction:  real True Class:  fake
# Test 371 Prediction:  fake True Class:  fake
# Test 372 Prediction:  real True Class:  fake
# Test 373 Prediction:  fake True Class:  fake
# Test 374 Prediction:  fake True Class:  fake
# Test 375 Prediction:  fake True Class:  fake
# Test 376 Prediction:  real True Class:  fake
# Test 377 Prediction:  fake True Class:  fake
# Test 378 Prediction:  fake True Class:  fake
# Test 379 Prediction:  fake True Class:  fake
# Test 380 Prediction:  real True Class:  fake
# Test 381 Prediction:  fake True Class:  fake
# Test 382 Prediction:  fake True Class:  fake
# Test 383 Prediction:  fake True Class:  fake
# Test 384 Prediction:  fake True Class:  fake
# Test 385 Prediction:  fake True Class:  fake
# Test 386 Prediction:  fake True Class:  fake
# Test 387 Prediction:  fake True Class:  fake
# Test 388 Prediction:  real True Class:  fake
# Test 389 Prediction:  fake True Class:  fake
# Test 390 Prediction:  fake True Class:  fake
# Test 391 Prediction:  real True Class:  fake
# Test 392 Prediction:  real True Class:  fake
# Test 393 Prediction:  fake True Class:  fake
# Test 394 Prediction:  fake True Class:  fake
# Test 395 Prediction:  fake True Class:  fake
# Test 396 Prediction:  fake True Class:  fake
# Test 397 Prediction:  fake True Class:  fake
# Test 398 Prediction:  real True Class:  fake
# Test 399 Prediction:  fake True Class:  fake
# Test 400 Prediction:  fake True Class:  fake
# Test 401 Prediction:  fake True Class:  fake
# Test 402 Prediction:  fake True Class:  fake
# Test 403 Prediction:  real True Class:  fake
# Test 404 Prediction:  real True Class:  fake
# Test 405 Prediction:  real True Class:  fake
# Test 406 Prediction:  fake True Class:  fake
# Test 407 Prediction:  real True Class:  fake
# Test 408 Prediction:  fake True Class:  fake
# Test 409 Prediction:  real True Class:  fake
# Test 410 Prediction:  fake True Class:  fake
# Test 411 Prediction:  fake True Class:  fake
# Test 412 Prediction:  fake True Class:  fake
# Test 413 Prediction:  real True Class:  fake
# Test 414 Prediction:  fake True Class:  fake
# Test 415 Prediction:  fake True Class:  fake
# Test 416 Prediction:  fake True Class:  fake
# Test 417 Prediction:  fake True Class:  fake
# Test 418 Prediction:  real True Class:  fake
# Test 419 Prediction:  fake True Class:  fake
# Test 420 Prediction:  fake True Class:  fake
# Test 421 Prediction:  fake True Class:  fake
# Test 422 Prediction:  fake True Class:  fake
# Test 423 Prediction:  real True Class:  fake
# Test 424 Prediction:  fake True Class:  fake
# Test 425 Prediction:  real True Class:  fake
# Test 426 Prediction:  real True Class:  fake
# Test 427 Prediction:  fake True Class:  fake
# Test 428 Prediction:  fake True Class:  fake
# Test 429 Prediction:  fake True Class:  fake
# Test 430 Prediction:  fake True Class:  fake
# Test 431 Prediction:  real True Class:  fake
# Test 432 Prediction:  real True Class:  fake
# Test 433 Prediction:  real True Class:  fake
# Test 434 Prediction:  real True Class:  fake
# Test 435 Prediction:  fake True Class:  fake
# Test 436 Prediction:  fake True Class:  fake
# Test 437 Prediction:  real True Class:  fake
# Test 438 Prediction:  real True Class:  fake
# Test 439 Prediction:  fake True Class:  fake
# Test 440 Prediction:  fake True Class:  fake
# Test 441 Prediction:  real True Class:  fake
# Test 442 Prediction:  fake True Class:  fake
# Test 443 Prediction:  fake True Class:  fake
# Test 444 Prediction:  fake True Class:  fake
# Test 445 Prediction:  fake True Class:  fake
# Test 446 Prediction:  fake True Class:  fake
# Test 447 Prediction:  real True Class:  fake
# Test 448 Prediction:  fake True Class:  fake
# Test 449 Prediction:  fake True Class:  fake
# Test 450 Prediction:  real True Class:  fake
# Test 451 Prediction:  real True Class:  fake
# Test 452 Prediction:  fake True Class:  fake
# Test 453 Prediction:  fake True Class:  fake
# Test 454 Prediction:  real True Class:  fake
# Test 455 Prediction:  fake True Class:  fake
# Test 456 Prediction:  fake True Class:  fake
# Test 457 Prediction:  fake True Class:  fake
# Test 458 Prediction:  fake True Class:  fake
# Test 459 Prediction:  fake True Class:  fake
# Test 460 Prediction:  fake True Class:  fake
# Test 461 Prediction:  fake True Class:  fake
# Test 462 Prediction:  real True Class:  fake
# Test 463 Prediction:  fake True Class:  fake
# Test 464 Prediction:  fake True Class:  fake
# Test 465 Prediction:  fake True Class:  fake
# Test 466 Prediction:  fake True Class:  fake
# Test 467 Prediction:  fake True Class:  fake
# Test 468 Prediction:  fake True Class:  fake
# Test 469 Prediction:  fake True Class:  fake
# Test 470 Prediction:  real True Class:  fake
# Test 471 Prediction:  real True Class:  fake
# Test 472 Prediction:  fake True Class:  fake
# Test 473 Prediction:  real True Class:  fake
# Test 474 Prediction:  fake True Class:  fake
# Test 475 Prediction:  fake True Class:  fake
# Test 476 Prediction:  real True Class:  fake
# Test 477 Prediction:  fake True Class:  fake
# Test 478 Prediction:  fake True Class:  fake
# Test 479 Prediction:  fake True Class:  fake
# Test 480 Prediction:  fake True Class:  fake
# Test 481 Prediction:  fake True Class:  fake
# Test 482 Prediction:  fake True Class:  fake
# Test 483 Prediction:  fake True Class:  fake
# Test 484 Prediction:  real True Class:  fake
# Test 485 Prediction:  fake True Class:  fake
# Test 486 Prediction:  fake True Class:  fake
# Test 487 Prediction:  real True Class:  fake
# Test 488 Prediction:  fake True Class:  fake
# Test 489 Prediction:  fake True Class:  fake
# Test 490 Prediction:  fake True Class:  fake
# Test 491 Prediction:  fake True Class:  fake
# Test 492 Prediction:  real True Class:  fake
# Test 493 Prediction:  fake True Class:  fake
# Test 494 Prediction:  fake True Class:  fake
# Test 495 Prediction:  fake True Class:  fake
# Test 496 Prediction:  fake True Class:  fake
# Test 497 Prediction:  fake True Class:  fake
# Test 498 Prediction:  real True Class:  fake
# Test 499 Prediction:  fake True Class:  fake
# Test 500 Prediction:  real True Class:  fake
# Test 501 Prediction:  fake True Class:  fake
# Test 502 Prediction:  real True Class:  fake
# Test 503 Prediction:  fake True Class:  fake
# Test 504 Prediction:  real True Class:  fake
# Test 505 Prediction:  real True Class:  fake
# Test 506 Prediction:  fake True Class:  fake
# Test 507 Prediction:  fake True Class:  fake
# Test 508 Prediction:  fake True Class:  fake
# Test 509 Prediction:  fake True Class:  fake
# Test 510 Prediction:  fake True Class:  fake
# Test 511 Prediction:  real True Class:  fake
# Done!
# Accuracy:  0.83984375
